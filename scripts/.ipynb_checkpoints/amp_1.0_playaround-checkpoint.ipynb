# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = pd.DataFrame.from_csv('../data/2016_US_County_Level_Presidential_Results.csv')
de = pd.DataFrame.from_csv('../data/equipment_WI.csv', index_col = False)

# %%
w = d[d['state_abbr']=='WI']

# %%
w['votes_dem_dig'] = 0

# %%
#int(str(w.iloc[0,0])[0])
for x in range(0,71):
    w.iloc[x,8] = int(str(w.iloc[x,0])[0])

# %%
w['votes_gop_dig'] = 0
for x in range(0,71):
    w.iloc[x,9] = int(str(w.iloc[x,1])[0])

# %%
w[0:5]
# Out:
#       votes_dem  votes_gop  total_votes   per_dem   per_gop state_abbr  \
# 2855       3780       5983        10107  0.373998  0.591966         WI
# 2856       4136       3428         7926  0.521827  0.432501         WI
# 2857       7881      13595        22514  0.350049  0.603846         WI
# 2858       4953       4125         9491  0.521863  0.434622         WI
# 2859      53358      67192       127497  0.418504  0.527008         WI
#
#           county_name  combined_fips  votes_dem_dig  votes_gop_dig
# 2855     Adams County          55001              3              5
# 2856   Ashland County          55003              4              3
# 2857    Barron County          55005              7              1
# 2858  Bayfield County          55007              4              4
# 2859     Brown County          55009              5              6

# %%
w.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11594b890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115bf8890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bd1a550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1044a3e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10babfb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bd69550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c060610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cd9c2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cf2ac90>]], dtype=object)

# %%
de[0:4]
# Out:
#               County               Municipality  \
# 0  ADAMS COUNTY - 01      CITY OF ADAMS - 01201
# 1  ADAMS COUNTY - 01      TOWN OF ADAMS - 01002
# 2  ADAMS COUNTY - 01  TOWN OF BIG FLATS - 01004
# 3  ADAMS COUNTY - 01    TOWN OF COLBURN - 01006
#
#                              Equipment  \
# 0        Optech/Command Central- Eagle
# 1                                None
# 2  Dominion (Sequoia)- Sequoia Insight
# 3                                None
#
#                       Accessible_Equipment
# 0                            ES&S Automark
# 1       Vote Pad-Vote Pad (non-electronic)
# 2  Dominion (Sequoia)/Command Central-Edge
# 3  Dominion (Sequoia)/Command Central-Edge

# %%
de.count()
# Out:
# County                  1853
# Municipality            1853
# Equipment               1853
# Accessible_Equipment    1853
# dtype: int64
