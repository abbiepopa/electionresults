# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = pd.DataFrame.from_csv('../data/2016_US_County_Level_Presidential_Results.csv')
de = pd.DataFrame.from_csv('../data/equipment_WI.csv')

# %%
de[0:5]
# Out:
#                                    Municipality  \
# County
# ADAMS COUNTY - 01         CITY OF ADAMS - 01201
# ADAMS COUNTY - 01         TOWN OF ADAMS - 01002
# ADAMS COUNTY - 01     TOWN OF BIG FLATS - 01004
# ADAMS COUNTY - 01       TOWN OF COLBURN - 01006
# ADAMS COUNTY - 01  TOWN OF DELL PRAIRIE - 01008
#
#                                              Equipment  \
# County
# ADAMS COUNTY - 01        Optech/Command Central- Eagle
# ADAMS COUNTY - 01                                None
# ADAMS COUNTY - 01  Dominion (Sequoia)- Sequoia Insight
# ADAMS COUNTY - 01                                None
# ADAMS COUNTY - 01                                None
#
#                                       Accessible_Equipment
# County
# ADAMS COUNTY - 01                            ES&S Automark
# ADAMS COUNTY - 01       Vote Pad-Vote Pad (non-electronic)
# ADAMS COUNTY - 01  Dominion (Sequoia)/Command Central-Edge
# ADAMS COUNTY - 01  Dominion (Sequoia)/Command Central-Edge
# ADAMS COUNTY - 01       Vote Pad-Vote Pad (non-electronic)

# %%
w = d[d['state_abbr']=='WI']

# %%
w['votes_dem_dig'] = 0

# %%
#int(str(w.iloc[0,0])[0])
for x in range(0,71):
    w.iloc[x,8] = int(str(w.iloc[x,0])[0])
# Out:
# 3780.0
# 3
# 4136.0
# 4
# 7881.0
# 7
# 4953.0
# 4
# 53358.0
# 5
# 2531.0
# 2
# 2948.0
# 2
# 9634.0
# 9
# 11875.0
# 1
# 4225.0
# 4
# 13525.0
# 1
# 3426.0
# 3
# 217506.0
# 2
# 13968.0
# 1
# 8026.0
# 8
# 11342.0
# 1
# 9025.0
# 9
# 27271.0
# 2
# 666.0
# 6
# 17391.0
# 1
# 1583.0
# 1
# 10047.0
# 1
# 9121.0
# 9
# 2700.0
# 2
# 6669.0
# 6
# 1273.0
# 1
# 3821.0
# 3
# 16559.0
# 1
# 4100.0
# 4
# 35770.0
# 3
# 3623.0
# 3
# 32402.0
# 3
# 3288.0
# 3
# 3260.0
# 3
# 5370.0
# 5
# 14563.0
# 1
# 26476.0
# 2
# 6243.0
# 6
# 2808.0
# 2
# 1003.0
# 1
# 288986.0
# 2
# 7047.0
# 7
# 5886.0
# 5
# 8103.0
# 8
# 38117.0
# 3
# 20167.0
# 2
# 1345.0
# 1
# 8380.0
# 8
# 7568.0
# 7
# 18524.0
# 1
# 2671.0
# 2
# 42506.0
# 4
# 3577.0
# 3
# 39336.0
# 3
# 2171.0
# 2
# 16050.0
# 1
# 2846.0
# 2
# 6056.0
# 6
# 22636.0
# 2
# 17496.0
# 1
# 2398.0
# 2
# 5645.0
# 5
# 6351.0
# 6
# 4769.0
# 4
# 18706.0
# 1
# 3283.0
# 3
# 20854.0
# 2
# 79199.0
# 7
# 8303.0
# 8
# 3802.0
# 3
# 37054.0
# 3

# %%
w['votes_gop_dig'] = 0
for x in range(0,71):
    w.iloc[x,9] = int(str(w.iloc[x,1])[0])

# %%
w[0:5]
# Out:
#       votes_dem  votes_gop  total_votes   per_dem   per_gop state_abbr  \
# 2855       3780       5983        10107  0.373998  0.591966         WI
# 2856       4136       3428         7926  0.521827  0.432501         WI
# 2857       7881      13595        22514  0.350049  0.603846         WI
# 2858       4953       4125         9491  0.521863  0.434622         WI
# 2859      53358      67192       127497  0.418504  0.527008         WI
#
#           county_name  combined_fips  votes_dem_dig  votes_gop_dig
# 2855     Adams County          55001              3              5
# 2856   Ashland County          55003              4              3
# 2857    Barron County          55005              7              1
# 2858  Bayfield County          55007              4              4
# 2859     Brown County          55009              5              6

# %%
w.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112f51cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113b7c890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c00350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113c62f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113ce8c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c887d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113ec9190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113f40d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113fb0310>]], dtype=object)
